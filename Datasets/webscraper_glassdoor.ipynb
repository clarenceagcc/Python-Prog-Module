# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, ElementNotInteractableException, StaleElementReferenceException
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium import webdriver
import time
import pandas as pd

# %%
def get_jobs_2(no_of_pages, verbose):
    links = ['https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22.htm?fromAge=14',
            'https://www.glassdoor.sg/Job/technical-support-specialist-jobs-SRCH_KO0,28.htm',
            'https://www.glassdoor.sg/Job/programmer-jobs-SRCH_KO0,10.htm',
            'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17.htm',
            'https://www.glassdoor.sg/Job/cyber-security-jobs-SRCH_KO0,14.htm',
            'https://www.glassdoor.sg/Job/game-developer-jobs-SRCH_KO0,14.htm',
            'https://www.glassdoor.sg/Job/data-analyst-jobs-SRCH_KO0,12.htm',
            'https://www.glassdoor.sg/Job/data-scientist-jobs-SRCH_KO0,14.htm',
            'https://www.glassdoor.sg/Job/systems-engineer-jobs-SRCH_KO0,16.htm',
            'https://www.glassdoor.sg/Job/cloud-engineer-jobs-SRCH_KO0,14.htm',
            'https://www.glassdoor.sg/Job/security-analyst-jobs-SRCH_KO0,16.htm',
            'https://www.glassdoor.sg/Job/it-architect-jobs-SRCH_KO0,12.htm',
            'https://www.glassdoor.sg/Job/cloud-architect-jobs-SRCH_KO0,15.htm',
            'https://www.glassdoor.sg/Job/cloud-software-engineer-jobs-SRCH_KO0,23.htm',
            'https://www.glassdoor.sg/Job/artificial-intelligence-jobs-SRCH_KO0,23.htm',
            'https://www.glassdoor.sg/Job/machine-learning-engineer-jobs-SRCH_KO0,25.htm',
            'https://www.glassdoor.sg/Job/systems-analyst-jobs-SRCH_KO0,15.htm',
            'https://www.glassdoor.sg/Job/big-data-engineer-jobs-SRCH_KO0,17.htm',
            'https://www.glassdoor.sg/Job/database-engineer-jobs-SRCH_KO0,17.htm',
            'https://www.glassdoor.sg/Job/web-developer-jobs-SRCH_KO0,13.htm',
            'https://www.glassdoor.sg/Job/front-end-developer-jobs-SRCH_KO0,19.htm',
            'https://www.glassdoor.sg/Job/back-end-developer-jobs-SRCH_KO0,18.htm',
            'https://www.glassdoor.sg/Job/full-stack-engineer-jobs-SRCH_KO0,19.htm',
            'https://www.glassdoor.sg/Job/data-engineer-jobs-SRCH_KO0,13.htm',
            'https://www.glassdoor.sg/Job/technical-support-engineer-jobs-SRCH_KO0,26.htm',
            'https://www.glassdoor.sg/Job/server-administrator-jobs-SRCH_KO0,20.htm',
            'https://www.glassdoor.sg/Job/penetration-tester-jobs-SRCH_KO0,18.htm',
            'https://www.glassdoor.sg/Job/data-engineer-jobs-SRCH_KO0,13.htm',
            'https://www.glassdoor.sg/Job/android-developer-jobs-SRCH_KO0,17.htm',
            'https://www.glassdoor.sg/Job/ai-data-scientist-jobs-SRCH_KO0,17.htm']
    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    #Initializing the webdriver
    options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')
    
    #Change the path to where chromedriver is in your home folder.
    service = Service(executable_path='/usr/bin/chromedriver')
    driver = webdriver.Chrome(service=service, options=options)
    jobs = []
    driver.set_window_size(1280, 1000)
    collected_all = False
    counter = 0
    
#//*[@id="MainCol"]/div[1]/ul/li[1]
#//*[@id="MainCol"]/div[1]/ul/li[2]

    while not collected_all:  #If true, should be still looking for new jobs.
        for pages in range(len(links)):
            page = 1
            url = links[pages]
            driver.get(url)
            while page <= no_of_pages:
                job_buttons = []
                print(f'PAGES : {pages}')
                print('Finding Job Buttons')
                time.sleep(1)
                for x in range(1,30):
                    job_buttons += driver.find_elements(By.XPATH, f'//*[@id="MainCol"]/div[1]/ul/li[{x}]')
                print(job_buttons)
        
                #Test for the "Sign Up" prompt and get rid of it.
                try:
                    driver.find_element(By.CLASS_NAME, 'selected').click()
                except ElementClickInterceptedException:
                    pass
        
                time.sleep(1)
        
                try:
                    driver.find_element(By.XPATH, '/html/body/div[12]/div/div/div/div[2]/button').click()  #clicking to the X.
                except NoSuchElementException:
                    pass
                
                try:
                    driver.find_element(By.XPATH, '//*[@id="LoginModal"]/div/div/div/div[2]/button').click()
                except NoSuchElementException:
                    pass
                for jobs_ in job_buttons:
                    print("Progress: {}".format("" + str(len(jobs))))
                    jobs_.click()

                    collected_successfully = False
                    while not collected_successfully:
                        try:
                            job_title = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[2]').text
                            company_name = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div').text
                            location = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[3]').text
                            job_desc = driver.find_element(By.XPATH, '//*[@id="JobDescriptionContainer"]').text
                            #career_oppr = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[3]/div/ul/span[3]').text
                            collected_successfully = True
                            
                        except:
                            time.sleep(.5)
                    try:
                        salary_estimate = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[4]/span').text
                    except NoSuchElementException:
                        salary_estimate = -1
                    try:
                        company_rating = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div/span').text
                    except NoSuchElementException:
                        company_rating = -1
                    try:
                        career_oppr = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[3]').text
                    except NoSuchElementException:
                        career_oppr = -1
                    try:
                        comp_benefits = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[6]').text
                    except NoSuchElementException:
                        comp_benefits = -1
                    try:
                        culture_values = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[9]').text
                    except NoSuchElementException:
                        culture_values = -1
                    try:
                        upper_mangement = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[12]').text
                    except NoSuchElementException:
                        upper_mangement = -1
                    try:
                        work_life_balance = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[15]').text
                    except NoSuchElementException:
                        work_life_balance = -1
                    try:
                        company_size = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[1]/span[2]').text
                    except NoSuchElementException:
                        company_size = -1
                    try:
                        company_founded = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[2]/span[2]').text
                    except NoSuchElementException:
                        company_founded = -1
                    try:
                        company_type = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[3]/span[2]').text
                    except NoSuchElementException:
                        company_type = -1
                    try:
                        company_industry = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[4]/span[2]').text
                    except NoSuchElementException:
                        company_industry = -1
                    try:
                        company_sector = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[5]/span[2]').text
                    except NoSuchElementException:
                        company_sector = -1
                    try:
                        company_revenue = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[6]/span[2]').text
                    except NoSuchElementException:
                        company_revenue = -1
    
                    try:
                        company_pros1 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[1]').text
                    except NoSuchElementException:
                        company_pros1 = -1
                    try:
                        company_pros2 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[2]').text
                    except NoSuchElementException:
                        company_pros2 = -1
                    try:
                        company_pros3 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[3]').text
                    except NoSuchElementException:
                        company_pros3 = -1
                    try:
                        company_pros4 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[4]').text
                    except NoSuchElementException:
                        company_pros4 = -1
                    try:
                        company_pros5 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[5]').text
                    except NoSuchElementException:
                        company_pros5 = -1


                    try:
                        company_cons1 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[1]').text
                    except NoSuchElementException:
                        company_cons1 = -1
                    try:
                        company_cons2 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[2]').text
                    except NoSuchElementException:
                        company_cons2 = -1
                    try:
                        company_cons3 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[3]').text
                    except NoSuchElementException:
                        company_cons3 = -1
                    try:
                        company_cons4 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[4]').text
                    except NoSuchElementException:
                        company_cons4 = -1
                    try:
                        company_cons5 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[5]').text
                    except NoSuchElementException:
                        company_cons5 = -1
                    


                    company_pros = []
                    company_cons = []
                    company_pros.extend([company_pros1, company_pros2, company_pros3, company_pros4, company_pros5])
                    company_cons.extend([company_cons1, company_cons2, company_cons3, company_cons4, company_cons5])
                    
                    jobs.append({'Job Title' : job_title,
                                'Company' : company_name,
                                'Company Rating' : company_rating,
                                'Job Description' : job_desc,
                                'Salary' : salary_estimate,
                                'Location' : location,
                                'Career Opportunities' : career_oppr,
                                'Company Benefits' : comp_benefits,
                                'Culture & Values' : culture_values,
                                'Upper Management' : upper_mangement,
                                'Work Life Balance' : work_life_balance,
                                'Company Pros Reviews' : company_pros,
                                'Company Cons Reviews' : company_cons,
                                'Company Size' : company_size,
                                'Company Founded' : company_founded,
                                'Company Type' : company_type,
                                'Company Industry' : company_industry,
                                'Company Sector' : company_sector,
                                'Company Revenue' : company_revenue})
                page += 1
                try:
                    driver.find_element(By.CLASS_NAME,'nextButton').click()
                    #driver.implicitly_wait(2)
                    #job_buttons = driver.find_elements(By.CLASS_NAME, 'react-job-listing')
                except NoSuchElementException:
                    print('cannot find')
                    break
        else:
            break

    
    return pd.DataFrame(jobs)

# %%
def get_jobs(num_jobs, verbose):
    links = ['https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22.htm?fromAge=14',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP2.htm?fromAge=14&includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP4.htm?fromAge=14&includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP3.htm?fromAge=14&includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP5.htm?includeNoSalaryJobs=true&fromAge=14',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP6.htm?includeNoSalaryJobs=true&fromAge=14',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP7.htm?includeNoSalaryJobs=true&fromAge=14',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP8.htm?includeNoSalaryJobs=true&fromAge=14']
    
    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    #Initializing the webdriver
    options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')
    
    #Change the path to where chromedriver is in your home folder.
    service = Service(executable_path='/usr/bin/chromedriver')
    driver = webdriver.Chrome(service=service, options=options)
    jobs = []
    driver.set_window_size(1280, 1000)
    collected_all = False
    counter = 0
    
    while not collected_all:  #If true, should be still looking for new jobs.
        if len(jobs) != num_jobs:
            for pages in range(0,35):
                if pages == 33:
                    collected_all = True
                if len(jobs) == num_jobs:
                    break
                print(f'PAGES : {pages}')
                url = links[pages]
                driver.get(url)
        
                time.sleep(.1)
                job_buttons = driver.find_elements(By.CLASS_NAME, 'react-job-listing')
        
                #Test for the "Sign Up" prompt and get rid of it.
                try:
                    driver.find_element(By.CLASS_NAME, 'selected').click()
                except ElementClickInterceptedException:
                    pass
        
                time.sleep(1)
        
                try:
                    driver.find_element(By.XPATH, '/html/body/div[12]/div/div/div/div[2]/button').click()  #clicking to the X.
                except NoSuchElementException:
                    pass
                
                try:
                    driver.find_element(By.XPATH, '//*[@id="LoginModal"]/div/div/div/div[2]/button').click()
                except NoSuchElementException:
                    pass
                for jobs_ in job_buttons:
                    print("Progress: {}".format("" + str(len(jobs)) + "/" + str(num_jobs)))
    
                    if len(jobs) == num_jobs:
                        break
                    
                    time.sleep(1)
                    jobs_.click()
                    collected_successfully = False
                    while not collected_successfully:
                        try:
                            job_title = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[2]').text
                            company_name = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div').text
                            location = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[3]').text
                            job_desc = driver.find_element(By.XPATH, '//*[@id="JobDescriptionContainer"]').text
                            #career_oppr = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[3]/div/ul/span[3]').text
                            collected_successfully = True
                            
                        except:
                            time.sleep(.5)
                    try:
                        salary_estimate = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[4]/span').text
                    except NoSuchElementException:
                        salary_estimate = -1
                    try:
                        company_rating = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div/span').text
                    except NoSuchElementException:
                        company_rating = -1
                    try:
                        career_oppr = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[3]').text
                    except NoSuchElementException:
                        career_oppr = -1
                    try:
                        comp_benefits = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[6]').text
                    except NoSuchElementException:
                        comp_benefits = -1
                    try:
                        culture_values = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[9]').text
                    except NoSuchElementException:
                        culture_values = -1
                    try:
                        upper_mangement = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[12]').text
                    except NoSuchElementException:
                        upper_mangement = -1
                    try:
                        work_life_balance = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[15]').text
                    except NoSuchElementException:
                        work_life_balance = -1
                        
                    try:
                        company_pros1 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[1]').text
                    except NoSuchElementException:
                        company_pros1 = -1
                    try:
                        company_pros2 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[2]').text
                    except NoSuchElementException:
                        company_pros2 = -1
                    try:
                        company_pros3 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[3]').text
                    except NoSuchElementException:
                        company_pros3 = -1
                    try:
                        company_pros4 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[4]').text
                    except NoSuchElementException:
                        company_pros4 = -1
                    try:
                        company_pros5 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[5]').text
                    except NoSuchElementException:
                        company_pros5 = -1


                    try:
                        company_cons1 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[1]').text
                    except NoSuchElementException:
                        company_cons1 = -1
                    try:
                        company_cons2 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[2]').text
                    except NoSuchElementException:
                        company_cons2 = -1
                    try:
                        company_cons3 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[3]').text
                    except NoSuchElementException:
                        company_cons3 = -1
                    try:
                        company_cons4 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[4]').text
                    except NoSuchElementException:
                        company_cons4 = -1
                    try:
                        company_cons5 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[5]').text
                    except NoSuchElementException:
                        company_cons5 = -1
                    


                    company_pros = []
                    company_cons = []
                    company_pros.extend([company_pros1, company_pros2, company_pros3, company_pros4, company_pros5])
                    company_cons.extend([company_cons1, company_cons2, company_cons3, company_cons4, company_cons5])
                    
                    jobs.append({'Job Title' : job_title,
                                'Company' : company_name,
                                'Company Rating' : company_rating,
                                'Job Description' : job_desc,
                                'Salary' : salary_estimate,
                                'Location' : location,
                                'Career Opportunities' : career_oppr,
                                'Company Benefits' : comp_benefits,
                                'Culture & Values' : culture_values,
                                'Upper Management' : upper_mangement,
                                'Work Life Balance' : work_life_balance,
                                'Company Pros Reviews' : company_pros,
                                'Company Cons Reviews' : company_cons})
        else:
            break

    
    return pd.DataFrame(jobs)

# %%
def get_jobs_3(no_of_pages, verbose):
    links = ['https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22.htm?fromAge=14',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17.htm',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP2.htm?fromAge=14&includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17_IP2.htm?includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP4.htm?fromAge=14&includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17_IP3.htm?includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP3.htm?fromAge=14&includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17_IP4.htm?includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP5.htm?includeNoSalaryJobs=true&fromAge=14',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17_IP5.htm?includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP6.htm?includeNoSalaryJobs=true&fromAge=14',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17_IP6.htm?includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP7.htm?includeNoSalaryJobs=true&fromAge=14',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17_IP7.htm?includeNoSalaryJobs=true',
             'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22_IP8.htm?includeNoSalaryJobs=true&fromAge=14',
             'https://www.glassdoor.sg/Job/software-engineer-jobs-SRCH_KO0,17_IP8.htm?includeNoSalaryJobs=true',]
    

    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    #Initializing the webdriver
    options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')
    
    #Change the path to where chromedriver is in your home folder.
    service = Service(executable_path='/usr/bin/chromedriver')
    driver = webdriver.Chrome(service=service, options=options)
    jobs = []
    driver.set_window_size(1280, 1000)
    collected_all = False
    counter = 0
    
#//*[@id="MainCol"]/div[1]/ul/li[1]
#//*[@id="MainCol"]/div[1]/ul/li[2]

    for pages in range(len(links)):
        url = links[pages]
        driver.get(url)
        job_buttons = []
        print(f'PAGES : {pages}')
        print('Finding Job Buttons')
        time.sleep(1)
        for x in range(1,30):
            job_buttons += driver.find_elements(By.XPATH, f'//*[@id="MainCol"]/div[1]/ul/li[{x}]')
        print(job_buttons)

        #Test for the "Sign Up" prompt and get rid of it.
        try:
            driver.find_element(By.CLASS_NAME, 'selected').click()
        except ElementClickInterceptedException:
            pass

        time.sleep(1)

        try:
            driver.find_element(By.XPATH, '/html/body/div[12]/div/div/div/div[2]/button').click()  #clicking to the X.
        except NoSuchElementException:
            pass
        
        try:
            driver.find_element(By.XPATH, '//*[@id="LoginModal"]/div/div/div/div[2]/button').click()
        except NoSuchElementException:
            pass
        for jobs_ in job_buttons:
            print("Progress: {}".format("" + str(len(jobs))))
            jobs_.click()

            collected_successfully = False
            while not collected_successfully:
                try:
                    job_title = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[2]').text
                    company_name = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div').text
                    location = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[3]').text
                    job_desc = driver.find_element(By.XPATH, '//*[@id="JobDescriptionContainer"]').text
                    #career_oppr = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[3]/div/ul/span[3]').text
                    collected_successfully = True
                    
                except:
                    time.sleep(.5)
            try:
                salary_estimate = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[4]/span').text
            except NoSuchElementException:
                salary_estimate = -1
            try:
                company_rating = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div/span').text
            except NoSuchElementException:
                company_rating = -1
            try:
                career_oppr = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[3]').text
            except NoSuchElementException:
                career_oppr = -1
            try:
                comp_benefits = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[6]').text
            except NoSuchElementException:
                comp_benefits = -1
            try:
                culture_values = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[9]').text
            except NoSuchElementException:
                culture_values = -1
            try:
                upper_mangement = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[12]').text
            except NoSuchElementException:
                upper_mangement = -1
            try:
                work_life_balance = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[2]/div[1]/div[4]/div/ul/span[15]').text
            except NoSuchElementException:
                work_life_balance = -1
            try:
                company_size = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[1]/span[2]').text
            except NoSuchElementException:
                company_size = -1
            try:
                company_founded = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[2]/span[2]').text
            except NoSuchElementException:
                company_founded = -1
            try:
                company_type = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[3]/span[2]').text
            except NoSuchElementException:
                company_type = -1
            try:
                company_industry = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[4]/span[2]').text
            except NoSuchElementException:
                company_industry = -1
            try:
                company_sector = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[5]/span[2]').text
            except NoSuchElementException:
                company_sector = -1
            try:
                company_revenue = driver.find_element(By.XPATH, '//*[@id="EmpBasicInfo"]/div[1]/div/div[6]/span[2]').text
            except NoSuchElementException:
                company_revenue = -1

            try:
                company_pros1 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[1]').text
            except NoSuchElementException:
                company_pros1 = -1
            try:
                company_pros2 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[2]').text
            except NoSuchElementException:
                company_pros2 = -1
            try:
                company_pros3 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[3]').text
            except NoSuchElementException:
                company_pros3 = -1
            try:
                company_pros4 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[4]').text
            except NoSuchElementException:
                company_pros4 = -1
            try:
                company_pros5 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[1]/p[5]').text
            except NoSuchElementException:
                company_pros5 = -1


            try:
                company_cons1 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[1]').text
            except NoSuchElementException:
                company_cons1 = -1
            try:
                company_cons2 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[2]').text
            except NoSuchElementException:
                company_cons2 = -1
            try:
                company_cons3 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[3]').text
            except NoSuchElementException:
                company_cons3 = -1
            try:
                company_cons4 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[4]').text
            except NoSuchElementException:
                company_cons4 = -1
            try:
                company_cons5 = driver.find_element(By.XPATH, '//*[@id="Reviews"]/div/div/div[2]/p[5]').text
            except NoSuchElementException:
                company_cons5 = -1
            


            company_pros = []
            company_cons = []
            company_pros.extend([company_pros1, company_pros2, company_pros3, company_pros4, company_pros5])
            company_cons.extend([company_cons1, company_cons2, company_cons3, company_cons4, company_cons5])
            
            jobs.append({'Job Title' : job_title,
                        'Company' : company_name,
                        'Company Rating' : company_rating,
                        'Job Description' : job_desc,
                        'Salary' : salary_estimate,
                        'Location' : location,
                        'Career Opportunities' : career_oppr,
                        'Company Benefits' : comp_benefits,
                        'Culture & Values' : culture_values,
                        'Upper Management' : upper_mangement,
                        'Work Life Balance' : work_life_balance,
                        'Company Pros Reviews' : company_pros,
                        'Company Cons Reviews' : company_cons,
                        'Company Size' : company_size,
                        'Company Founded' : company_founded,
                        'Company Type' : company_type,
                        'Company Industry' : company_industry,
                        'Company Sector' : company_sector,
                        'Company Revenue' : company_revenue})

    
    return pd.DataFrame(jobs)

# %%
no_of_jobs = 990
start_pg = 1
end_pg = 10

df_info = get_jobs_2(8, False)
df_info
# Out:
# PAGES : 0
# Finding Job Buttons
# ...

# %%
pd.set_option('display.max_rows', None)
df_info
# Out:
#                                              Job Title  \
# 0    No Interview + Start Immediate * 3 Months Temp...
# 1         Staff Analyst - Information Technology (B2B)
# 2    Information Technology Analyst (Banking - Fres...
# 3    Information Technology - Mobile Applications D...
# 4    Information Technology Engineer (IBM Mainframe...
# 5    VP, Information Technology Risk & Governance M...
# 6    2024 Apple Internship - Information Systems an...
# 7    Associate - Senior Support Analyst (Singapore)...
# 8    Information Technology – Mobile Applications D...
# 9    Associate - Lead Business Analyst (Singapore) ...
# 10          Assistant Manager - Information Technology
# 11                                        IT Executive
# 12      Information Technology (Navitaire COE) Analyst
# 13          Information Technology Operations Engineer
# 14   Full Stack Web Developer (Information Technology)
# 15         Manager, Information Technology (Navitaire)
# ...

# %%
df_machine.to_csv('out_with_pros_jobdesc_test.csv')
