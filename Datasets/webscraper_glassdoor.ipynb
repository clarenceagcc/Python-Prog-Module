# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium import webdriver
import time
import pandas as pd

# %%
def get_jobs(num_jobs, verbose):
    
    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    #Initializing the webdriver
    options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')
    
    #Change the path to where chromedriver is in your home folder.
    service = Service(executable_path='/usr/bin/chromedriver')
    driver = webdriver.Chrome(service=service, options=options)
    driver.set_window_size(1120, 1000)

    url = 'https://www.glassdoor.sg/Job/information-technology-jobs-SRCH_KO0,22.htm?fromAge=14'
    driver.get(url)
    jobs = []

    while len(jobs) < num_jobs:  #If true, should be still looking for new jobs.

        #Let the page load. Change this number based on your internet speed.
        #Or, wait until the webpage is loaded, instead of hardcoding it.
        #Test for the "Sign Up" prompt and get rid of it.
        #try:
        #    driver.find_element_by_class_name("selected").click()
        #except ElementClickInterceptedException:
        #    pass

        time.sleep(.1)
        job_buttons = driver.find_elements(By.CLASS_NAME, 'react-job-listing')

        #Test for the "Sign Up" prompt and get rid of it.
        try:
            driver.find_element(By.CLASS_NAME, 'selected').click()
        except ElementClickInterceptedException:
            pass

        time.sleep(.1)

        try:
            driver.find_element(By.XPATH, '/html/body/div[12]/div/div/div/div[2]/button').click()  #clicking to the X.
        except NoSuchElementException:
            pass

        for jobs_ in job_buttons:
            print("Progress: {}".format("" + str(len(jobs)) + "/" + str(num_jobs)))
            if len(jobs) >= num_jobs:
                break
            
            time.sleep(1)
            jobs_.click()
            collected_successfully = False
            while not collected_successfully:
                try:
                    job_title = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[2]').text
                    company_name = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div').text
                    location = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[3]').text
                    collected_successfully = True
                    
                except:
                    print("PROBLEM")
                    time.sleep(5)
            try:
                salary_estimate = driver.find_element(By.XPATH, '//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[4]/span').text
            except NoSuchElementException:
                salary_estimate = -1 #You need to set a "not found value. It's important."
            
            try:
                company_rating = driver.find_element(By.XPATH,'//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/div/span').text
            except NoSuchElementException:
                rating = -1 #You need to set a "not found value. It's important."
    
            jobs.append({'Job Title' : job_title,
                        'Company' : company_name,
                        'Company Rating' : company_rating,
                        'Salary' : salary_estimate,
                        'Location' : location})
                        

    
    return pd.DataFrame(jobs)

# %%
df = get_jobs(20, False)
df
# Out:
# Progress: 0/20
# PROBLEM
# Progress: 1/20
# PROBLEM
# Progress: 2/20
# PROBLEM
# Progress: 3/20
# PROBLEM
# Progress: 4/20
# PROBLEM
# Progress: 5/20
# PROBLEM
# Progress: 6/20
# PROBLEM
# Progress: 7/20
# PROBLEM
# Progress: 8/20
# PROBLEM
# Progress: 9/20
# PROBLEM
# Progress: 10/20
# PROBLEM
# Progress: 11/20
# PROBLEM
# Progress: 12/20
# PROBLEM
# Progress: 13/20
# PROBLEM
# Progress: 14/20
# PROBLEM
# Progress: 15/20
# PROBLEM
# Progress: 16/20
# PROBLEM
# Progress: 17/20
# PROBLEM
# Progress: 18/20
# PROBLEM
# Progress: 19/20
# PROBLEM
# Progress: 20/20
#                                             Job Title  \
# 0        Staff Analyst - Information Technology (B2B)
# 1   Information Technology Analyst (Banking - Fres...
# 2   Information Technology - Mobile Applications D...
# 3   Information Technology Engineer (IBM Mainframe...
# 4      Information Technology (Navitaire COE) Analyst
# 5   Information Technology – Mobile Applications D...
# 6   VP, Information Technology Risk & Governance M...
# 7                                           IT Intern
# 8                                          IT Support
# 9                                          IT Support
# 10             Information Technology Support Manager
# 11                                      IT Technician
# 12         Assistant Manager - Information Technology
# 13                               SERVICE DESK MANAGER
# 14           Admin Executive - Information Technology
# 15                                IT Support Engineer
# 16                                 IT Project Manager
# 17  Full Stack Web Developer (Information Technology)
# 18  Regional Information Technology Manager - Fina...
# 19                   INFORMATION TECHNOLOGY EXECUTIVE
#
#                                     Company Company Rating  \
# 0                Infineon Technologies\n4.2            4.2
# 1                D L RESOURCES PTE LTD\n3.3            3.3
# 2                   Singapore Airlines\n3.8            3.8
# 3                D L RESOURCES PTE LTD\n3.3            3.3
# 4                      SCOOT PTE. LTD.\n3.4            3.4
# 5                   Singapore Airlines\n3.8            3.8
# 6        SLOANE SHOREY CONSULTING PTE. LTD.            3.8
# 7          Draeger Singapore Pte. Ltd.\n3.7            3.7
# 8             Apro Asian Protection Pte Ltd            3.7
# 9         FRONTIER FORCE TECHNOLOGY PTE LTD            3.7
# 10         CENTRECOM TECHNOLOGIES PTE. LTD.            3.7
# 11                          Day One Pte Ltd            3.7
# 12  ISS INTERNATIONAL SCHOOL PTE. LTD.\n3.0            3.0
# 13             TERRA SYSTEMS PTE. LTD.\n3.1            3.1
# 14                       ITCAN Pte Ltd\n3.8            3.8
# 15                        Wits Info Pte Ltd            3.8
# 16                                CI&T(思艾特)            3.8
# 17                     SCOOT PTE. LTD.\n3.4            3.4
# 18          Gravitas Recruitment Group\n4.1            4.1
# 19  Sunshine Welfare Action Mission (SWAMI)            4.1
#
#                                     Salary              Location
# 0                                       -1             Singapore
# 1       Employer Provided Salary:$2K - $6K             Singapore
# 2             $89K - $96K (Glassdoor Est.)             Singapore
# 3       Employer Provided Salary:$3K - $6K             Singapore
# 4       Employer Provided Salary:$4K - $8K             Singapore
# 5             $89K - $96K (Glassdoor Est.)             Singapore
# 6     Employer Provided Salary:$13K - $15K             Singapore
# 7                                       -1     Queenstown Estate
# 8       Employer Provided Salary:$3K - $3K  Jurong East New Town
# 9       Employer Provided Salary:$3K - $4K             Singapore
# 10      Employer Provided Salary:$5K - $6K             Singapore
# 11      Employer Provided Salary:$2K - $4K    Toa Payoh New Town
# 12      Employer Provided Salary:$4K - $5K    Bukit Merah Estate
# 13      Employer Provided Salary:$3K - $8K      Hougang New Town
# 14                                      -1             Singapore
# 15      Employer Provided Salary:$3K - $3K             Singapore
# 16      Employer Provided Salary:$6K - $8K                Remote
# 17     Employer Provided Salary:$5K - $10K             Singapore
# 18  Employer Provided Salary:$150K - $200K             Singapore
# 19      Employer Provided Salary:$3K - $4K             Singapore
